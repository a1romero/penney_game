# %%
import combined_penney

# %%
combined_penney.play_game(n=1,var=2)
# Out:
# Testing sequences: P1: 000, P2: 000
# (000, 000)
# P1 Tricks: 2
# P2 Tricks: 0
# Player 1 wins!
#
# Testing sequences: P1: 000, P2: 001
# (000, 001)
# P1 Tricks: 2
# P2 Tricks: 3
# Player 2 wins!
#
# Testing sequences: P1: 000, P2: 010
# (000, 010)
# P1 Tricks: 2
# P2 Tricks: 7
# Player 2 wins!
#
# Testing sequences: P1: 000, P2: 011
# (000, 011)
# P1 Tricks: 2
# P2 Tricks: 3
# Player 2 wins!
#
# Testing sequences: P1: 000, P2: 100
# (000, 100)
# P1 Tricks: 0
# P2 Tricks: 6
# Player 2 wins!
#
# Testing sequences: P1: 000, P2: 101
# (000, 101)
# P1 Tricks: 2
# P2 Tricks: 8
# Player 2 wins!
#
# Testing sequences: P1: 000, P2: 110
# (000, 110)
# P1 Tricks: 1
# P2 Tricks: 5
# Player 2 wins!
#
# Testing sequences: P1: 000, P2: 111
# (000, 111)
# P1 Tricks: 2
# P2 Tricks: 2
# Player 2 wins!
#
# Testing sequences: P1: 001, P2: 000
# (001, 000)
# P1 Tricks: 3
# P2 Tricks: 2
# Player 1 wins!
#
# Testing sequences: P1: 001, P2: 001
# (001, 001)
# P1 Tricks: 5
# P2 Tricks: 0
# Player 1 wins!
#
# ...
